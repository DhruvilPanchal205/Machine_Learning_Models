# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvilPanchal205/Data-Models-and-ETL-using-SQL/blob/main/Linear_Regression_Walmart_Sales_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#libries pandas for data processing, numpy for artihmetic operations, scikit learn for linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as mtp
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


#Load the data and set dataframes
file_path = "/content/Walmart.csv"
df = pd.read_csv(file_path)

# %%
#selecting independing and depending variables
x = df.iloc[:, 5].values
y = df.iloc[:, 2].values

# %%
#dividing datasets into training and testing
x_train, x_test, y_train, y_test =train_test_split(x, y, train_size=0.8, random_state=0)

# Assuming x_train is a 1D array
x_train = x_train.reshape(-1, 1)

# %%
#train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Reshaping x_test to 2D if it's a single feature
y_pred = model.predict(x_test.reshape(-1, 1))
x_pred = model.predict(x_train.reshape(-1, 1))

# %%
#model evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 316180198646.6184
# R-squared: -0.00037258992596322926

# %%
#visualizing the Test set results
mtp.scatter(x_test, y_test, color="blue")
mtp.plot(x_train, x_pred, color="red")
mtp.title("Salary vs Experience (Test Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary(In Rupees)")
mtp.show()
